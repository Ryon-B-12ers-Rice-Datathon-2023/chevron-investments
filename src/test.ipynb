# %%
import pandas as pd

# %%
pd.read_csv(r'../data/transformed_data.csv')
# Out:
#     StateCode  Year  CO2 Emissions (Mmt)  TotalNumberofInvestments  \
# 0          AK  2015            35.027804                      16.0
# 1          AK  2016            33.405611                      14.0
# 2          AK  2017            33.729130                      18.0
# 3          AK  2018            34.514589                      44.0
# 4          AK  2019            34.259440                      32.0
# ..        ...   ...                  ...                       ...
# 263        X3  2018                  NaN                       NaN
# 264        X5  2015                  NaN                       NaN
# 265        X5  2016                  NaN                       NaN
# 266        X5  2017                  NaN                       NaN
# 267        X5  2018                  NaN                       NaN
#
#      TotalAmountofAssistance  BDFDB  BDPRP  BFFDB  BFPRP    CLPRB  ...  \
# 0                  3345612.0   21.0    4.0   21.0    4.0  17747.0  ...
# ...

# %%
x = [1, 2, 3]
x[1: -1]
# Out:
# [2]
