# %%
import pandas as pd

# %%
df = pd.read_csv(r'../data/Investment_Data_Full.csv')

pivot_df = df.pivot_table(index='Year', columns=['StateCode','MSN'],

values=['Amount', 'TotalNumberofInvestments', 'TotalAmountofAssistance', 'CO2 Emissions (Mmt)'])

# %%
pivot_df
# Out:
#           Amount                                                          \
# StateCode     AK
# MSN        BDFDB BDPRP BFFDB BFPRP    CLPRB   CLPRK   CLPRP  COPRK EMFDB
# Year
# 2015        21.0   4.0  21.0   4.0  17747.0  15.073  1177.0  5.717   0.0
# 2016        27.0   5.0  27.0   5.0  13942.0  14.957   932.0  5.722   0.0
# 2017        29.0   5.0  29.0   5.0  14365.0  14.978   959.0  5.723   0.0
# 2018        15.0   3.0  15.0   3.0  13752.0  15.253   902.0  5.706   0.0
# 2019         0.0   0.0   0.0   0.0  14867.0  15.252   975.0  5.698   0.0
# 2020         0.0   0.0   0.0   0.0  15523.0  15.206  1021.0  5.691   0.0
#
#                  ... TotalNumberofInvestments                                \
# StateCode        ...                       WY
# MSN       ENPRP  ...                    REPRB SOTCB TEPRB TETCB WDEXB WDPRB
# Year             ...
# 2015        0.0  ...                     18.0  18.0  18.0  18.0  18.0  18.0
# ...

# %%
pivot_df.columns
# Out:
# MultiIndex([(                  'Amount', 'AK', 'BDFDB'),
#             (                  'Amount', 'AK', 'BDPRP'),
#             (                  'Amount', 'AK', 'BFFDB'),
#             (                  'Amount', 'AK', 'BFPRP'),
#             (                  'Amount', 'AK', 'CLPRB'),
#             (                  'Amount', 'AK', 'CLPRK'),
#             (                  'Amount', 'AK', 'CLPRP'),
#             (                  'Amount', 'AK', 'COPRK'),
#             (                  'Amount', 'AK', 'EMFDB'),
#             (                  'Amount', 'AK', 'ENPRP'),
#             ...
#             ('TotalNumberofInvestments', 'WY', 'REPRB'),
#             ('TotalNumberofInvestments', 'WY', 'SOTCB'),
#             ('TotalNumberofInvestments', 'WY', 'TEPRB'),
#             ('TotalNumberofInvestments', 'WY', 'TETCB'),
#             ('TotalNumberofInvestments', 'WY', 'WDEXB'),
#             ('TotalNumberofInvestments', 'WY', 'WDPRB'),
# ...

# %%
pivot_df.to_csv(r'../data/15-20_lstm_assistance_msn.csv')

# %%
included = []

for column in pivot_df.columns:
    if column[0] == 'Amount':
        continue
    if (column[0], column[1]) not in included:
        included.append((column[0], column[1]))
    else:
        pivot_df.drop(columns=column, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 9
#       7     included.append((column[0], column[1]))
#       8 else:
# ----> 9     pivot_df.drop(column, inplace=True)
#
# File c:\Users\danie\Projects\chevron_investment\venv\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\danie\Projects\chevron_investment\venv\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...
